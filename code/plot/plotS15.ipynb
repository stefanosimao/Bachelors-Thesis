# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn
#un terzo ogni, un terzo accomulo 4 poi 12 diverge
#bs 32 48 64 80
#corrected
df = pd.read_csv('Project/data_s15.csv')

# %%
df
# Out:
#                                             exp_number  num_nodes    bs  \
# 0                                                    2        2.0  80.0
# 1                                                    3        2.0  80.0
# 2                                                    1        2.0  80.0
# 3                                                    2        2.0  64.0
# 4                                                    1        2.0  64.0
# ..                                                 ...        ...   ...
# 188                                                  1       16.0  48.0
# 189                                                  3       16.0  48.0
# 190                                                  2       16.0  32.0
# 191                                                  3       16.0  32.0
# 192  sgonalve@daint106:/scratch/snx3000/sgonalve/pr...        NaN   NaN
#
#      num_epochs        acc       time
# 0          20.0  98.550003  24.630090
# 1          20.0  98.769997  24.747639
# 2          20.0  98.510002  24.666417
# 3          20.0  98.750000  28.606662
# 4          20.0  98.680000  28.573358
# ..          ...        ...        ...
# 188        40.0  11.350000  15.281043
# 189        40.0  11.350000  15.262536
# 190        40.0  19.809999  19.042820
# 191        40.0  11.350000  18.803162
# 192         NaN        NaN        NaN
#
# [193 rows x 6 columns]

# %%
n20_df = df.query('num_epochs == 20')
seaborn.set_style("whitegrid")
g1 = seaborn.relplot(data=n20_df, x='num_nodes', y='acc', hue='bs', kind="line", legend = True, err_style="bars")
g1.fig.suptitle("20 epochs", y = 0.95)
g1.set(ylabel= "Accuracy", xlabel="num_nodes")
plt.legend(labels=["Batch size = 32", "Batch size = 48", "Batch size = 64", "Batch size = 80"])
plt.show()

n40_df = df.query('num_epochs == 40')
seaborn.set_style("whitegrid")
g2 = seaborn.relplot(data=n40_df, x='num_nodes', y='acc', hue='bs', kind="line", legend = False, err_style="bars")
g2.fig.suptitle("40 epochs", y = 0.95)
g2.set(ylabel= "Accuracy", xlabel="num_nodes")
plt.legend(labels=["Batch size = 32", "Batch size = 48", "Batch size = 64", "Batch size = 80"])
plt.show()

# %%
n20_df = df.query('num_epochs == 20')
seaborn.set_style("whitegrid")
g1 = seaborn.relplot(data=n20_df, x='num_nodes', y='time', hue='bs', kind="line", legend = False, err_style="bars")
g1.fig.suptitle("20 epochs", y = 0.95)
g1.set(ylabel= "Time(s)", xlabel="num_nodes")
plt.legend(labels=["Batch size = 32", "Batch size = 48", "Batch size = 64", "Batch size = 80"])
plt.show()

n40_df = df.query('num_epochs == 40')
seaborn.set_style("whitegrid")
g2 = seaborn.relplot(data=n40_df, x='num_nodes', y='time', hue='bs', kind="line", legend = False, err_style="bars")
g2.fig.suptitle("40 epochs", y = 0.95)
g2.set(ylabel= "Time(s)", xlabel="num_nodes")
plt.legend(labels=["Batch size = 32", "Batch size = 48", "Batch size = 64", "Batch size = 80"])
plt.show()
