# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn
#un terzo ogni, un terzo accomulo 8 poi 16 diverge
#bs 48 64 96
#e 20
#corrected
df = pd.read_csv('Project/data_s20.csv')

# %%
df
# Out:
#     exp_number  num_nodes  bs  num_epochs        acc       time
# 0            1          4  48          20  98.320000  19.015644
# 1            3          2  96          20  98.000000  22.434296
# 2            1          2  96          20  98.220001  22.590870
# 3            2          2  96          20  98.400002  22.643528
# 4            2          2  64          20  98.750000  27.758612
# ..         ...        ...  ..         ...        ...        ...
# 67           2         16  64          20  36.840000   6.623715
# 68           2         16  96          20  93.430000   5.978919
# 69           3         16  48          20  91.510002   7.459673
# 70           1         16  48          20  40.240002   7.476724
# 71           3         16  96          20  45.650002   5.911587
#
# [72 rows x 6 columns]

# %%
n20_df = df.query('num_epochs == 20')
seaborn.set_style("whitegrid")
g2 = seaborn.relplot(data=n20_df, x='num_nodes', y='acc', hue='bs', kind="line", legend = True, err_style="bars")
g2.fig.suptitle("20 epochs", y = 0.95)
g2.set(ylabel= "Accuracy", xlabel="num_nodes")
plt.legend(labels=["Batch size = 48", "Batch size = 64", "Batch size = 96"])
plt.show()

# %%
n20_df = df.query('num_epochs == 20')
seaborn.set_style("whitegrid")
g1 = seaborn.relplot(data=n20_df, x='num_nodes', y='time', hue='bs', kind="line", legend = False, err_style="bars")
g1.fig.suptitle("20 epochs", y = 0.95)
g1.set(ylabel= "Time(s)", xlabel="num_nodes")
plt.legend(labels=["Batch size = 32", "Batch size = 48", "Batch size = 64"])
plt.show()
