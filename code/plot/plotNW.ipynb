# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn

# %%
df = pd.read_csv('Project/test_nw.csv')

# %%
list_of_column_names = list(df.columns)

print('List of column names : ',
      list_of_column_names)
# Out:
# List of column names :  ['num_workers', 'num_nodes', 'bs', 'num_epochs', 'acc', 'time']

# %%
df
# Out:
#      num_workers  num_nodes   bs  num_epochs    acc       time
# 0              4          2   50          16  98.50  28.943489
# 1              5          2   50          16  98.60  29.629933
# 2              3          2   50          16  98.60  28.682208
# 3              2          2   50          16  98.89  35.747037
# 4              6          2   50          16  98.64  29.767773
# ..           ...        ...  ...         ...    ...        ...
# 355            9         16  250          16  98.07   5.460421
# 356           11         16  250          16  98.04   6.196174
# 357           14         16  250          16  98.06   7.598071
# 358           10         16  250          16  98.08   5.795433
# 359           16         16  250          16  98.08   7.883866
#
# [360 rows x 6 columns]

# %%
df.plot(kind='scatter',x='num_workers',y='time',color='red')
plt.show()

# %%
#df.set_index('num_workers', inplace=True)
#f.groupby('num_nodes')['time'].plot(legend=True)

# %%
n2_df = df.query('num_nodes == 2')
seaborn.set_style("whitegrid")
g2 = seaborn.relplot(data=n2_df, x='num_workers', y='time', hue='bs', kind="line", legend = False)
g2.fig.suptitle("2 nodes", y = 0.95)
g2.set(ylabel= "Time(s)", xlabel="num_workers")
plt.legend(labels=["Batch size = 50","Batch size = 150", "Batch size = 250"])
plt.savefig('n2_nw.png')
plt.show()

# %%
n4_df = df.query('num_nodes == 4')
g4 = seaborn.relplot(data=n4_df, x='num_workers', y='time', hue='bs', kind="line", legend = False)
g4.fig.suptitle("4 nodes", y = 0.95)
g4.set(ylabel= "Time(s)", xlabel="num_workers")
plt.legend(labels=["Batch size = 50","Batch size = 150", "Batch size = 250"])
plt.savefig('n4_nw.png')
plt.show()

# %%
n6_df = df.query('num_nodes == 6')
g6 = seaborn.relplot(data=n6_df, x='num_workers', y='time', hue='bs', kind="line", legend = False)
g6.fig.suptitle("6 nodes", y = 0.95)
g6.set(ylabel= "Time(s)", xlabel="num_workers")
plt.legend(labels=["Batch size = 50","Batch size = 150", "Batch size = 250"])
plt.savefig('n6_nw.png')
plt.show()

# %%
n8_df = df.query('num_nodes == 8')
g8 = seaborn.relplot(data=n8_df, x='num_workers', y='time', hue='bs', kind="line", legend = False)
g8.fig.suptitle("8 nodes", y = 0.95)
g8.set(ylabel= "Time(s)", xlabel="num_workers")
plt.legend(labels=["Batch size = 50","Batch size = 150", "Batch size = 250"])
plt.savefig('n8_nw.png')
plt.show()

# %%
n10_df = df.query('num_nodes == 10')
g10 = seaborn.relplot(data=n10_df, x='num_workers', y='time', hue='bs', kind="line", legend = False)
g10.fig.suptitle("10 nodes", y = 0.95)
g10.set(ylabel= "Time(s)", xlabel="num_workers")
plt.legend(labels=["Batch size = 50","Batch size = 150", "Batch size = 250"])
plt.savefig('n10_nw.png')
plt.show()

# %%
n12_df = df.query('num_nodes == 12')
g12 = seaborn.relplot(data=n12_df, x='num_workers', y='time', hue='bs', kind="line", legend = False)
g12.fig.suptitle("12 nodes", y = 0.95)
g12.set(ylabel= "Time(s)", xlabel="num_workers")
plt.legend(labels=["Batch size = 50","Batch size = 150", "Batch size = 250"])
plt.savefig('n12_nw.png')
plt.show()

# %%
n14_df = df.query('num_nodes == 14')
g14 = seaborn.relplot(data=n14_df, x='num_workers', y='time', hue='bs', kind="line", legend = False)
g14.fig.suptitle("14 nodes", y = 0.95)
g14.set(ylabel= "Time(s)", xlabel="num_workers")
plt.legend(labels=["Batch size = 50","Batch size = 150", "Batch size = 250"])
plt.savefig('n14_nw.png')
plt.show()

# %%
n16_df = df.query('num_nodes == 16')
g16 = seaborn.relplot(data=n16_df, x='num_workers', y='time', hue='bs', kind="line", legend = False)
g16.fig.suptitle("16 nodes", y = 0.95)
g16.set(ylabel= "Time(s)", xlabel="num_workers")
plt.legend(labels=["Batch size = 50","Batch size = 150", "Batch size = 250"])
plt.savefig('n16_nw.png')
plt.show()

# %%
n16_df
# Out:
#      num_workers  num_nodes   bs  num_epochs    acc       time
# 313            3         16   50          16  98.92   5.542727
# 314            2         16   50          16  98.96   5.935603
# 317            1         16   50          16  98.99   9.206169
# 318            0         16   50          16  98.88  11.272108
# 319            4         16   50          16  98.90   5.910962
# 320            6         16   50          16  98.88   6.460359
# 321            5         16   50          16  98.93   5.982128
# 322            9         16   50          16  98.93   7.450874
# 323            7         16   50          16  98.92   6.917698
# 324            8         16   50          16  98.90   7.048534
# 325           10         16   50          16  98.96   7.790984
# 326           11         16   50          16  98.96   8.135988
# 327           12         16   50          16  98.92   8.560177
# 328           16         16   50          16  98.94  10.196599
# 329           14         16   50          16  98.93  10.982008
# 330            3         16  150          16  98.41   4.759694
# 331            6         16  150          16  98.21   4.823689
# 332            9         16  150          16  98.21   5.702832
# 333            8         16  150          16  98.40   5.242251
# 334           10         16  150          16  98.39   6.092719
# 335            7         16  150          16  98.46   4.899173
# 336            1         16  150          16  98.25   8.107913
# 337            5         16  150          16  98.39   4.649080
# 338            4         16  150          16  98.23   4.575669
# 339            2         16  150          16  98.30   5.163690
# 340            0         16  150          16  98.26   8.104602
# 341            4         16  250          16  98.07   4.534174
# 342            5         16  250          16  98.05   4.603161
# 343            2         16  250          16  98.08   5.457982
# 344            3         16  250          16  98.04   4.426480
# 345           12         16  150          16  98.17   7.033237
# 346           14         16  150          16  98.43   7.619334
# 347           16         16  150          16  98.24   8.122608
# 348           11         16  150          16  98.29   6.399536
# 349            1         16  250          16  98.09   7.702317
# 350            6         16  250          16  98.08   4.725545
# 351            0         16  250          16  98.09   7.269719
# 352            8         16  250          16  98.07   5.316111
# 353            7         16  250          16  98.08   5.076986
# 354           12         16  250          16  98.07   6.561859
# 355            9         16  250          16  98.07   5.460421
# 356           11         16  250          16  98.04   6.196174
# 357           14         16  250          16  98.06   7.598071
# 358           10         16  250          16  98.08   5.795433
# 359           16         16  250          16  98.08   7.883866

# %%
num_workers_cases = {
      2: {50: 3, 150: 8, 250: 10},
      4: {50: 3, 150: 8, 250: 9},
      6: {50: 3, 150: 6, 250: 7},
      8: {50: 3, 150: 6, 250: 5},
      10: {50: 3, 150: 5, 250: 5},
      12: {50: 3, 150: 4, 250: 4},
      14: {50: 3, 150: 4, 250: 4},
      16: {50: 3, 150: 4, 250: 3},
}
def adapt_num_workers(world_size, batch_size):
      return num_workers_cases.get(world_size, {}).get(batch_size, 6)

n_w = adapt_num_workers(4, 250)
print(n_w)
# Out:
# 9
